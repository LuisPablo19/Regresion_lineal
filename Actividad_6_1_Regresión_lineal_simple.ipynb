# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPablo19/Regresion_lineal/blob/main/Actividad_6_1_Regresi%C3%B3n_lineal_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Actividad 6.1: Regresión Lineal Simple**
# ##Luis Pablo Padilla Barbosa
# ##A00572040

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files 
from sklearn.linear_model import LinearRegression

# %%
EUA = pd.read_csv("California_EUA (Limpio).csv", encoding = "unicode_escape", index_col = 'Unnamed: 0')
Mexico = pd.read_csv("DF_Mexico (Limpio).csv", index_col = 'Unnamed: 0')
Espana = pd.read_csv("Girona_España (Limpio).csv", encoding = "unicode_escape", index_col = 'Unnamed: 0')

# %%
def correlacion(df, dependiente, independiente): 
  df1 = pd.DataFrame()
  df1 = df.copy()
  Vars_Indep= df[[independiente]]
  Var_Dep= df[dependiente]
  model= LinearRegression()
  model.fit(X=Vars_Indep, y=Var_Dep)
  y_pred= model.predict(X=df[[independiente]])
  df1.insert(0, 'Predicciones', y_pred)
  plt.scatter(x=independiente, y=dependiente, color="blue", data=df1)
  plt.scatter(x=independiente, y='Predicciones', color="red", data=df1)
  plt.ylabel(dependiente)
  plt.xlabel(independiente)
  plt.show()
  coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
  print("El coeficiente de determinación es: ", coef_Deter)
  coef_Correl=np.sqrt(coef_Deter)
  print("El coeficiente de correlación es: ", coef_Correl)
  return (coef_Deter, coef_Correl)

# %%
def correlaciones_df(df, nombre):
  df2 = pd.DataFrame()
  lista_coef_Deter = []
  lista_coef_Correl = []
  lista = ['Modelo 1', 'Modelo 2', 'Modelo 3', 'Modelo 4', 'Modelo 5', 'Modelo 6']
  coef_Deter, coef_Correl = correlacion(df, 'host_acceptance_rate', 'host_response_rate')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  coef_Deter, coef_Correl = correlacion(df, 'host_acceptance_rate', 'price')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  coef_Deter, coef_Correl = correlacion(df, 'host_acceptance_rate', 'number_of_reviews')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  coef_Deter, coef_Correl = correlacion(df, 'review_scores_location', 'review_scores_cleanliness')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  coef_Deter, coef_Correl = correlacion(df, 'availability_365', 'number_of_reviews')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  coef_Deter, coef_Correl = correlacion(df, 'reviews_per_month', 'review_scores_communication')
  lista_coef_Deter.append(coef_Deter)
  lista_coef_Correl.append(coef_Correl)
  df2[nombre] = lista
  df2['Coeficiente determinación'] = lista_coef_Deter
  df2['Coeficiente correlación'] = lista_coef_Correl
  return df2

# %% [markdown]
# ##**Hotel Room**

# %%
EUA_entireroom_corr = correlaciones_df(EUA[EUA['room_type']=='Entire home/apt'], 'EUA')
# Out:
# El coeficiente de determinación es:  0.04293940673334218
# El coeficiente de correlación es:  0.20721825868716826
# El coeficiente de determinación es:  0.0005343974621976333
# El coeficiente de correlación es:  0.023117038352644427
# El coeficiente de determinación es:  0.008326525889989167
# El coeficiente de correlación es:  0.09124979939698041
# El coeficiente de determinación es:  0.09189625729375195
# El coeficiente de correlación es:  0.3031439547372699
# El coeficiente de determinación es:  0.01097685507017565
# El coeficiente de correlación es:  0.10477048759157156
# El coeficiente de determinación es:  0.05396960716162358
# El coeficiente de correlación es:  0.23231359659224335

# %%
Mexico_entireroom_corr = correlaciones_df(Mexico[Mexico['room_type']=='Entire home/apt'], 'México')
# Out:
# El coeficiente de determinación es:  0.12074513808012433
# El coeficiente de correlación es:  0.347484011258251
# El coeficiente de determinación es:  8.081001223292361e-06
# El coeficiente de correlación es:  0.0028427101898175202
# El coeficiente de determinación es:  0.019226689619606607
# El coeficiente de correlación es:  0.1386603390288896
# El coeficiente de determinación es:  0.0863889486352889
# El coeficiente de correlación es:  0.29391996977968154
# El coeficiente de determinación es:  0.003939867761715066
# El coeficiente de correlación es:  0.06276836593153486
# El coeficiente de determinación es:  0.00882494419096902
# El coeficiente de correlación es:  0.09394117409831015

# %%
Espana_entireroom_corr = correlaciones_df(Espana[Espana['room_type']=='Entire home/apt'], 'España')
# Out:
# El coeficiente de determinación es:  0.0833606541579176
# El coeficiente de correlación es:  0.28872245177318234
# El coeficiente de determinación es:  0.00010614354767801704
# El coeficiente de correlación es:  0.010302599073923873
# El coeficiente de determinación es:  0.0004408672650045853
# El coeficiente de correlación es:  0.020996839405124413
# El coeficiente de determinación es:  0.08460507001760098
# El coeficiente de correlación es:  0.2908695068541922
# El coeficiente de determinación es:  0.0022764309090844703
# El coeficiente de correlación es:  0.047711957715906715
# El coeficiente de determinación es:  0.021573326140608695
# El coeficiente de correlación es:  0.1468786102215319

# %%
paises = pd.concat([EUA_entireroom_corr, Mexico_entireroom_corr, Espana_entireroom_corr], axis = 1)
paises
# Out:
#         EUA  Coeficiente determinación  Coeficiente correlación    México  \
# 0  Modelo 1                   0.042939                 0.207218  Modelo 1
# 1  Modelo 2                   0.000534                 0.023117  Modelo 2
# 2  Modelo 3                   0.008327                 0.091250  Modelo 3
# 3  Modelo 4                   0.091896                 0.303144  Modelo 4
# 4  Modelo 5                   0.010977                 0.104770  Modelo 5
# 5  Modelo 6                   0.053970                 0.232314  Modelo 6
#
#    Coeficiente determinación  Coeficiente correlación    España  \
# 0                   0.120745                 0.347484  Modelo 1
# 1                   0.000008                 0.002843  Modelo 2
# 2                   0.019227                 0.138660  Modelo 3
# 3                   0.086389                 0.293920  Modelo 4
# 4                   0.003940                 0.062768  Modelo 5
# 5                   0.008825                 0.093941  Modelo 6
#
#    Coeficiente determinación  Coeficiente correlación
# 0                   0.083361                 0.288722
# 1                   0.000106                 0.010303
# 2                   0.000441                 0.020997
# 3                   0.084605                 0.290870
# 4                   0.002276                 0.047712
# 5                   0.021573                 0.146879

# %% [markdown]
# ##**Private Room**

# %%
EUA_privateroom_corr = correlaciones_df(EUA[EUA['room_type']=='Private room'], 'EUA')
# Out:
# El coeficiente de determinación es:  0.025609933442360844
# El coeficiente de correlación es:  0.16003103899669227
# El coeficiente de determinación es:  0.0018580767213612903
# El coeficiente de correlación es:  0.043105414060896
# El coeficiente de determinación es:  0.015191962739025566
# El coeficiente de correlación es:  0.12325568035196417
# El coeficiente de determinación es:  0.05886023394665352
# El coeficiente de correlación es:  0.2426112815733298
# El coeficiente de determinación es:  0.011576045280019986
# El coeficiente de correlación es:  0.1075920316753057
# El coeficiente de determinación es:  0.04916788769117619
# El coeficiente de correlación es:  0.22173833157840842

# %%
Mexico_privateroom_corr = correlaciones_df(Mexico[Mexico['room_type']=='Private room'], 'México')
# Out:
# El coeficiente de determinación es:  0.11940465395747701
# El coeficiente de correlación es:  0.34554978506356654
# El coeficiente de determinación es:  1.8359290937075556e-05
# El coeficiente de correlación es:  0.004284774315769216
# El coeficiente de determinación es:  0.02426172728555709
# El coeficiente de correlación es:  0.1557617645173458
# El coeficiente de determinación es:  0.1746334930412634
# El coeficiente de correlación es:  0.417891724064097
# El coeficiente de determinación es:  0.005180477985288978
# El coeficiente de correlación es:  0.07197553740882369
# El coeficiente de determinación es:  0.07275374030333959
# El coeficiente de correlación es:  0.2697290127208039

# %%
Espana_privateroom_corr = correlaciones_df(Espana[Espana['room_type']=='Private room'], 'España')
# Out:
# El coeficiente de determinación es:  0.12073295973630005
# El coeficiente de correlación es:  0.3474664872132276
# El coeficiente de determinación es:  0.0017339232804460813
# El coeficiente de correlación es:  0.04164040442222051
# El coeficiente de determinación es:  0.004162495709220115
# El coeficiente de correlación es:  0.06451740624994247
# El coeficiente de determinación es:  0.15031868923948866
# El coeficiente de correlación es:  0.3877095423632086
# El coeficiente de determinación es:  2.0395513942172983e-06
# El coeficiente de correlación es:  0.0014281286336381952
# El coeficiente de determinación es:  0.06829459865121024
# El coeficiente de correlación es:  0.26133235285974493

# %%
paises = pd.concat([EUA_privateroom_corr, Mexico_privateroom_corr, Espana_privateroom_corr], axis = 1)
paises
# Out:
#         EUA  Coeficiente determinación  Coeficiente correlación    México  \
# 0  Modelo 1                   0.025610                 0.160031  Modelo 1
# 1  Modelo 2                   0.001858                 0.043105  Modelo 2
# 2  Modelo 3                   0.015192                 0.123256  Modelo 3
# 3  Modelo 4                   0.058860                 0.242611  Modelo 4
# 4  Modelo 5                   0.011576                 0.107592  Modelo 5
# 5  Modelo 6                   0.049168                 0.221738  Modelo 6
#
#    Coeficiente determinación  Coeficiente correlación    España  \
# 0                   0.119405                 0.345550  Modelo 1
# 1                   0.000018                 0.004285  Modelo 2
# 2                   0.024262                 0.155762  Modelo 3
# 3                   0.174633                 0.417892  Modelo 4
# 4                   0.005180                 0.071976  Modelo 5
# 5                   0.072754                 0.269729  Modelo 6
#
#    Coeficiente determinación  Coeficiente correlación
# 0                   0.120733                 0.347466
# 1                   0.001734                 0.041640
# 2                   0.004162                 0.064517
# 3                   0.150319                 0.387710
# 4                   0.000002                 0.001428
# 5                   0.068295                 0.261332
